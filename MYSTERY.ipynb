# %% [markdown]
# # SQL Murder Mystery
#
# ## Can you find out whodunnit?
#
# ![A decorative illustration of a detective looking at an evidence board.](https://mystery.knightlab.com/174092-clue-illustration.png)
#
# There's been a Murder in SQL City! The SQL Murder Mystery is designed to be both a self-directed lesson to learn SQL concepts and commands and a fun game for experienced SQL users to solve an intriguing crime.
#
# ## SQL sleuths start here
#
# A crime has taken place and the detective needs your help. The detective gave you the crime scene report, but you somehow lost it. You vaguely remember that the crime was a **​murder​**that occurred sometime on ​**Jan.15, 2018​** and that it took place in ​**SQL City​**. Start by retrieving the corresponding crime scene report from the police department’s database.
#
# ### Exploring the Database Structure
#
# Experienced SQL users can often use database queries to infer the structure of a database. But each database system has different ways of managing this information. The SQL Murder Mystery is built using SQLite. Use this SQL command to find the tables in the Murder Mystery database.
#
# Run this query to find the names of the tables in this database.
#
# SQLite-specific tip: the `sqlite_master` table is SQLite's catalog of tables and schemas, and other databases expose metadata differently.
#
# This command is specific to SQLite. For other databases, you'll have to learn their specific syntax.

# %% [markdown]
# # SQL Murder Mystery
#
# ## Can you find out whodunnit?
#
# ![A decorative illustration of a detective looking at an evidence board.](https://mystery.knightlab.com/174092-clue-illustration.png)
#
# There's been a Murder in SQL City! The SQL Murder Mystery is designed to be both a self-directed lesson to learn SQL concepts and commands and a fun game for experienced SQL users to solve an intriguing crime.
#
# ## SQL sleuths start here
#
# A crime has taken place and the detective needs your help. The detective gave you the crime scene report, but you somehow lost it. You vaguely remember that the crime was a **​murder​**that occurred sometime on ​**Jan.15, 2018​** and that it took place in ​**SQL City​**. Start by retrieving the corresponding crime scene report from the police department’s database.
#
# ### Exploring the Database Structure
#
# Experienced SQL users can often use database queries to infer the structure of a database. But each database system has different ways of managing this information. The SQL Murder Mystery is built using SQLite. Use this SQL command to find the tables in the Murder Mystery database.
#
# Run this query to find the names of the tables in this database.
#
# SQLite-specific tip: the `sqlite_master` table is SQLite's catalog of tables and schemas, and other databases expose metadata differently.
#
# This command is specific to SQLite. For other databases, you'll have to learn their specific syntax.

# %%
# Install required packages
# %pip install jupysql sqlalchemy pandas --quiet

# Load SQL magic
# %load_ext sql

# Connect to the database
# %sql sqlite:///sql-murder-mystery.db
#%config SqlMagic.style = 'table'
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Connecting to 'sqlite:///sql-murder-mystery.db'

# %% [markdown]
# Besides knowing the table names, you need to know how each table is structured. The way this works is also dependent upon which database technology you use. Here's how you do it with SQLite.
#
# Run this query to find the structure of the `crime_scene_report` table
#
# Change the value of 'name' to see the structure of the other tables you learned about with the previous query.

# %%
# %%sql
# SELECT sql
# FROM sqlite_master
# where name = 'crime_scene_report'
# Out:
# Running query in 'sqlite:///sql-murder-mystery.db'
# +-----------------------------------+
# |                sql                |
# +-----------------------------------+
# | CREATE TABLE crime_scene_report ( |
# |               date integer,       |
# |                 type text,        |
# |             description text,     |
# |                 city text         |
# |                   )               |
# +-----------------------------------+

# %%
# %%sql
# SELECT description
# FROM crime_scene_report
# WHERE date = 20180115 AND city = 'SQL City'
# Out:
# Running query in 'sqlite:///sql-murder-mystery.db'
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |                                                                                        description                                                                                        |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |                                                        Hamilton: Lee, do you yield? Burr: You shot him in the side! Yes he yields!                                                        |
# |                                                                                      Report Not Found                                                                                     |
# | Security footage shows that there were 2 witnesses. The first witness lives at the last house on "Northwestern Dr". The second witness, named Annabel, lives somewhere on "Franklin Ave". |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
# %%sql
# SELECT name, address_number
# FROM person
# WHERE address_street_name = "Northwestern Dr"
# ORDER BY address_number DESC
# Out:
# Running query in 'sqlite:///sql-murder-mystery.db'
# +---------------------+----------------+
# |         name        | address_number |
# +---------------------+----------------+
# |    Morty Schapiro   |      4919      |
# |    Lasonya Wildey   |      3824      |
# |    Sophie Tiberio   |      3755      |
# |    Torie Thalmann   |      3697      |
# |    Coretta Cubie    |      3631      |
# |     Cody Schiel     |      3524      |
# |    Emmitt Aceuedo   |      3491      |
# | Leonora Wolfsberger |      3483      |
# |    Freddie Ellzey   |      3449      |
# |     Boris Bijou     |      3327      |
# +---------------------+----------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# SELECT i.transcript, p.name
# FROM interview AS i
# LEFT JOIN person AS p
#     ON i.person_id = p.id
# WHERE p.name = "Annabel Miller" OR p.name = "Morty Schapiro"
# Out:
# Running query in 'sqlite:///sql-murder-mystery.db'
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+
# |                                                                                                            transcript                                                                                                           |      name      |
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+
# | I heard a gunshot and then saw a man run out. He had a "Get Fit Now Gym" bag. The membership number on the bag started with "48Z". Only gold members have those bags. The man got into a car with a plate that included "H42W". | Morty Schapiro |
# |                                                      I saw the murder happen, and I recognized the killer from my gym when I was working out last week on January the 9th.                                                      | Annabel Miller |
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+

# %%
# %%sql
# SELECT m.name, c.membership_id
# FROM get_fit_now_member AS m
# LEFT JOIN get_fit_now_check_in AS c
# ON m.id = c.membership_id
# WHERE c.check_in_date = "20180109" AND m.membership_status = "gold"
# Out:
# Running query in 'sqlite:///sql-murder-mystery.db'
# +----------------+---------------+
# |      name      | membership_id |
# +----------------+---------------+
# | Sarita Bartosh |     XTE42     |
# | Burton Grippe  |     6LSTG     |
# | Carmen Dimick  |     GE5Q8     |
# |  Joe Germuska  |     48Z7A     |
# | Jeremy Bowers  |     48Z55     |
# | Annabel Miller |     90081     |
# +----------------+---------------+

# %%
# %%sql
# SELECT d.id, p.name, d.plate_number
# FROM person AS p
# LEFT JOIN drivers_license AS d
# ON p.license_id = d.id
# WHERE p.id IN (
#     SELECT person_id
#     FROM get_fit_now_member
#     WHERE id = "48Z7A" OR id = "48Z55"
# )
# Out:
# Running query in 'sqlite:///sql-murder-mystery.db'
# +--------+---------------+--------------+
# |   id   |      name     | plate_number |
# +--------+---------------+--------------+
# |  None  |  Joe Germuska |     None     |
# | 423327 | Jeremy Bowers |    0H42W2    |
# +--------+---------------+--------------+

# %% [markdown]
# ### The rest is up to you!
#
# If you're really comfortable with SQL, you can probably get it from here. To help, here is the schema diagram:
#
# ![schema diagram](schema.png)
#
# Use your knowledge of the database schema and SQL commands to find out who committed the murder.
# ### Check your solution
#
# Did you find the killer? When you think you know the answer, submit your suspect using the following code and find out if you're right.

# %%
# %%sql
# INSERT INTO solution VALUES (1, 'Jeremy Bowers');
# SELECT value FROM solution;
# Out:
# Running query in 'sqlite:///sql-murder-mystery.db'
# 1 rows affected.
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |                                                                                                                                                                                               value                                                                                                                                                                                                |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Congrats, you found the murderer! But wait, there's more... If you think you're up for a challenge, try querying the interview transcript of the murderer to find the real villain behind this crime. If you feel especially confident in your SQL skills, try to complete this final step with no more than 2 queries. Use this same INSERT statement with your new suspect to check your answer. |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
# %%sql
# SELECT i.transcript
# FROM interview AS i
# LEFT JOIN person AS p
# ON p.id = i.person_id
# WHERE p.license_id = "423327" AND p.name = "Jeremy Bowers"
# ORDER BY i.transcript DESC
# Out:
# Running query in 'sqlite:///sql-murder-mystery.db'
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |                                                                                                                    transcript                                                                                                                    |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | I was hired by a woman with a lot of money. I don't know her name but I know she's around 5'5" (65") or 5'7" (67"). She has red hair and she drives a Tesla Model S. I know that she attended the SQL Symphony Concert 3 times in December 2017. |
# |                                                                                                                                                                                                                                                  |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
# %%sql
# SELECT p.name, d.car_model, d.hair_color, p.id, d.car_make
# FROM person AS p
# LEFT JOIN drivers_license AS d
# ON p.license_id = d.id
# WHERE (d.height = 65 or d.height = 67) AND d.hair_color = "red" AND d.gender = "female" AND d.car_make = "Tesla"
# Out:
# Running query in 'sqlite:///sql-murder-mystery.db'
# +----------+-----------+------------+-------+----------+
# |   name   | car_model | hair_color |   id  | car_make |
# +----------+-----------+------------+-------+----------+
# | Red Korb |  Model S  |    red     | 78881 |  Tesla   |
# +----------+-----------+------------+-------+----------+

# %%
# %%sql
# SELECT f.event_name, f.date, p.id, p.name, f.person_id
# FROM facebook_event_checkin AS f
# LEFT JOIN person AS p
# ON f.person_id = p.id
# WHERE f.event_name = "SQL Symphony Concert" AND f.date LIKE '%201712%'
# Out:
# Running query in 'sqlite:///sql-murder-mystery.db'
# +----------------------+----------+-------+-------------------+-----------+
# |      event_name      |   date   |   id  |        name       | person_id |
# +----------------------+----------+-------+-------------------+-----------+
# | SQL Symphony Concert | 20171225 | 62596 |   Avery Spieler   |   62596   |
# | SQL Symphony Concert | 20171214 | 19260 |    Elmer Rosell   |   19260   |
# | SQL Symphony Concert | 20171220 | 58898 |  Enedina Cassells |   58898   |
# | SQL Symphony Concert | 20171214 | 69699 | Sanjuanita Gorius |   69699   |
# | SQL Symphony Concert | 20171213 | 19292 |   Enrique Feltes  |   19292   |
# | SQL Symphony Concert | 20171207 | 43366 |    Bret Windler   |   43366   |
# | SQL Symphony Concert | 20171212 | 92343 |  Freida Betschart |   92343   |
# | SQL Symphony Concert | 20171220 | 28582 |  Denyse Bloomgren |   28582   |
# | SQL Symphony Concert | 20171215 | 28582 |  Denyse Bloomgren |   28582   |
# | SQL Symphony Concert | 20171202 | 81526 |    Odis Manteca   |   81526   |
# +----------------------+----------+-------+-------------------+-----------+
# Truncated to displaylimit of 10.

# %%
# Install required packages
# %pip install jupysql sqlalchemy pandas --quiet

# Load SQL magic
# %load_ext sql

# Connect to the database
# %sql sqlite:///sql-murder-mystery.db
#%config SqlMagic.style = 'table'
# Out:
# Note: you may need to restart the kernel to use updated packages.
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %%sql
# SELECT name
# FROM sqlite_master
# Out:
# Running query in 'sqlite:///sql-murder-mystery.db'
# +---------------------------------------+
# |                  name                 |
# +---------------------------------------+
# |           crime_scene_report          |
# |            drivers_license            |
# |         facebook_event_checkin        |
# |               interview               |
# |           get_fit_now_member          |
# | sqlite_autoindex_get_fit_now_member_1 |
# |          get_fit_now_check_in         |
# |                solution               |
# |             check_solution            |
# |                 income                |
# +---------------------------------------+
# Truncated to displaylimit of 10.

# %% [markdown]
# Besides knowing the table names, you need to know how each table is structured. The way this works is also dependent upon which database technology you use. Here's how you do it with SQLite.
#
# Run this query to find the structure of the `crime_scene_report` table
#
# Change the value of 'name' to see the structure of the other tables you learned about with the previous query.

# %%
# %%sql
# SELECT sql
# FROM sqlite_master
# where name = 'crime_scene_report'
# Out:
# Running query in 'sqlite:///sql-murder-mystery.db'
# +-----------------------------------+
# |                sql                |
# +-----------------------------------+
# | CREATE TABLE crime_scene_report ( |
# |               date integer,       |
# |                 type text,        |
# |             description text,     |
# |                 city text         |
# |                   )               |
# +-----------------------------------+

# %% [markdown]
# ### The rest is up to you!
#
# If you're really comfortable with SQL, you can probably get it from here. To help, here is the schema diagram:
#
# ![schema diagram](schema.png)
#
# Use your knowledge of the database schema and SQL commands to find out who committed the murder.
# ### Check your solution
#
# Did you find the killer? When you think you know the answer, submit your suspect using the following code and find out if you're right.

# %% [markdown]
# # SQL Murder Mystery
#
# ## Can you find out whodunnit?
#
# ![A decorative illustration of a detective looking at an evidence board.](https://mystery.knightlab.com/174092-clue-illustration.png)
#
# There's been a Murder in SQL City! The SQL Murder Mystery is designed to be both a self-directed lesson to learn SQL concepts and commands and a fun game for experienced SQL users to solve an intriguing crime.
#
# ## SQL sleuths start here
#
# A crime has taken place and the detective needs your help. The detective gave you the crime scene report, but you somehow lost it. You vaguely remember that the crime was a **​murder​**that occurred sometime on ​**Jan.15, 2018​** and that it took place in ​**SQL City​**. Start by retrieving the corresponding crime scene report from the police department’s database.
#
# ### Exploring the Database Structure
#
# Experienced SQL users can often use database queries to infer the structure of a database. But each database system has different ways of managing this information. The SQL Murder Mystery is built using SQLite. Use this SQL command to find the tables in the Murder Mystery database.
#
# Run this query to find the names of the tables in this database.
#
# SQLite-specific tip: the `sqlite_master` table is SQLite's catalog of tables and schemas, and other databases expose metadata differently.
#
# This command is specific to SQLite. For other databases, you'll have to learn their specific syntax.

# %%
# Install required packages
# %pip install jupysql sqlalchemy pandas --quiet

# Load SQL magic
# %load_ext sql

# Connect to the database
# %sql sqlite:///sql-murder-mystery.db
#%config SqlMagic.style = 'table'
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Connecting to 'sqlite:///sql-murder-mystery.db'

# %% [markdown]
# Besides knowing the table names, you need to know how each table is structured. The way this works is also dependent upon which database technology you use. Here's how you do it with SQLite.
#
# Run this query to find the structure of the `crime_scene_report` table
#
# Change the value of 'name' to see the structure of the other tables you learned about with the previous query.

# %%
# %%sql
# SELECT sql
# FROM sqlite_master
# where name = 'crime_scene_report'
# Out:
# Running query in 'sqlite:///sql-murder-mystery.db'
# +-----------------------------------+
# |                sql                |
# +-----------------------------------+
# | CREATE TABLE crime_scene_report ( |
# |               date integer,       |
# |                 type text,        |
# |             description text,     |
# |                 city text         |
# |                   )               |
# +-----------------------------------+

# %%
# %%sql
# SELECT description
# FROM crime_scene_report
# WHERE date = 20180115 AND city = 'SQL City'
# Out:
# Running query in 'sqlite:///sql-murder-mystery.db'
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |                                                                                        description                                                                                        |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |                                                        Hamilton: Lee, do you yield? Burr: You shot him in the side! Yes he yields!                                                        |
# |                                                                                      Report Not Found                                                                                     |
# | Security footage shows that there were 2 witnesses. The first witness lives at the last house on "Northwestern Dr". The second witness, named Annabel, lives somewhere on "Franklin Ave". |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
# %%sql
# SELECT name, address_number
# FROM person
# WHERE address_street_name = "Northwestern Dr"
# ORDER BY address_number DESC
# Out:
# Running query in 'sqlite:///sql-murder-mystery.db'
# +---------------------+----------------+
# |         name        | address_number |
# +---------------------+----------------+
# |    Morty Schapiro   |      4919      |
# |    Lasonya Wildey   |      3824      |
# |    Sophie Tiberio   |      3755      |
# |    Torie Thalmann   |      3697      |
# |    Coretta Cubie    |      3631      |
# |     Cody Schiel     |      3524      |
# |    Emmitt Aceuedo   |      3491      |
# | Leonora Wolfsberger |      3483      |
# |    Freddie Ellzey   |      3449      |
# |     Boris Bijou     |      3327      |
# +---------------------+----------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# SELECT i.transcript, p.name
# FROM interview AS i
# LEFT JOIN person AS p
#     ON i.person_id = p.id
# WHERE p.name = "Annabel Miller" OR p.name = "Morty Schapiro"
# Out:
# Running query in 'sqlite:///sql-murder-mystery.db'
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+
# |                                                                                                            transcript                                                                                                           |      name      |
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+
# | I heard a gunshot and then saw a man run out. He had a "Get Fit Now Gym" bag. The membership number on the bag started with "48Z". Only gold members have those bags. The man got into a car with a plate that included "H42W". | Morty Schapiro |
# |                                                      I saw the murder happen, and I recognized the killer from my gym when I was working out last week on January the 9th.                                                      | Annabel Miller |
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+

# %%
# %%sql
# SELECT m.name, c.membership_id
# FROM get_fit_now_member AS m
# LEFT JOIN get_fit_now_check_in AS c
# ON m.id = c.membership_id
# WHERE c.check_in_date = "20180109" AND m.membership_status = "gold"
# Out:
# Running query in 'sqlite:///sql-murder-mystery.db'
# +----------------+---------------+
# |      name      | membership_id |
# +----------------+---------------+
# | Sarita Bartosh |     XTE42     |
# | Burton Grippe  |     6LSTG     |
# | Carmen Dimick  |     GE5Q8     |
# |  Joe Germuska  |     48Z7A     |
# | Jeremy Bowers  |     48Z55     |
# | Annabel Miller |     90081     |
# +----------------+---------------+

# %%
# %%sql
# SELECT d.id, p.name, d.plate_number
# FROM person AS p
# LEFT JOIN drivers_license AS d
# ON p.license_id = d.id
# WHERE p.id IN (
#     SELECT person_id
#     FROM get_fit_now_member
#     WHERE id = "48Z7A" OR id = "48Z55"
# )
# Out:
# Running query in 'sqlite:///sql-murder-mystery.db'
# +--------+---------------+--------------+
# |   id   |      name     | plate_number |
# +--------+---------------+--------------+
# |  None  |  Joe Germuska |     None     |
# | 423327 | Jeremy Bowers |    0H42W2    |
# +--------+---------------+--------------+

# %% [markdown]
# ### The rest is up to you!
#
# If you're really comfortable with SQL, you can probably get it from here. To help, here is the schema diagram:
#
# ![schema diagram](schema.png)
#
# Use your knowledge of the database schema and SQL commands to find out who committed the murder.
# ### Check your solution
#
# Did you find the killer? When you think you know the answer, submit your suspect using the following code and find out if you're right.

# %%
# %%sql
# INSERT INTO solution VALUES (1, 'Jeremy Bowers');
# SELECT value FROM solution;
# Out:
# Running query in 'sqlite:///sql-murder-mystery.db'
# 1 rows affected.
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |                                                                                                                                                                                               value                                                                                                                                                                                                |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Congrats, you found the murderer! But wait, there's more... If you think you're up for a challenge, try querying the interview transcript of the murderer to find the real villain behind this crime. If you feel especially confident in your SQL skills, try to complete this final step with no more than 2 queries. Use this same INSERT statement with your new suspect to check your answer. |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
# %%sql
# SELECT i.transcript
# FROM interview AS i
# LEFT JOIN person AS p
# ON p.id = i.person_id
# WHERE p.license_id = "423327" AND p.name = "Jeremy Bowers"
# ORDER BY i.transcript DESC
# Out:
# Running query in 'sqlite:///sql-murder-mystery.db'
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |                                                                                                                    transcript                                                                                                                    |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | I was hired by a woman with a lot of money. I don't know her name but I know she's around 5'5" (65") or 5'7" (67"). She has red hair and she drives a Tesla Model S. I know that she attended the SQL Symphony Concert 3 times in December 2017. |
# |                                                                                                                                                                                                                                                  |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
# %%sql
# SELECT p.name, d.car_model, d.hair_color, p.id, d.car_make
# FROM person AS p
# LEFT JOIN drivers_license AS d
# ON p.license_id = d.id
# WHERE (d.height = 65 or d.height = 67) AND d.hair_color = "red" AND d.gender = "female" AND d.car_make = "Tesla"
# Out:
# Running query in 'sqlite:///sql-murder-mystery.db'
# +----------+-----------+------------+-------+----------+
# |   name   | car_model | hair_color |   id  | car_make |
# +----------+-----------+------------+-------+----------+
# | Red Korb |  Model S  |    red     | 78881 |  Tesla   |
# +----------+-----------+------------+-------+----------+

# %%
# %%sql
# SELECT f.event_name, f.date, p.id, p.name, f.person_id
# FROM facebook_event_checkin AS f
# LEFT JOIN person AS p
# ON f.person_id = p.id
# WHERE f.event_name = "SQL Symphony Concert" AND f.date LIKE '%201712%'
# Out:
# Running query in 'sqlite:///sql-murder-mystery.db'
# +----------------------+----------+-------+-------------------+-----------+
# |      event_name      |   date   |   id  |        name       | person_id |
# +----------------------+----------+-------+-------------------+-----------+
# | SQL Symphony Concert | 20171225 | 62596 |   Avery Spieler   |   62596   |
# | SQL Symphony Concert | 20171214 | 19260 |    Elmer Rosell   |   19260   |
# | SQL Symphony Concert | 20171220 | 58898 |  Enedina Cassells |   58898   |
# | SQL Symphony Concert | 20171214 | 69699 | Sanjuanita Gorius |   69699   |
# | SQL Symphony Concert | 20171213 | 19292 |   Enrique Feltes  |   19292   |
# | SQL Symphony Concert | 20171207 | 43366 |    Bret Windler   |   43366   |
# | SQL Symphony Concert | 20171212 | 92343 |  Freida Betschart |   92343   |
# | SQL Symphony Concert | 20171220 | 28582 |  Denyse Bloomgren |   28582   |
# | SQL Symphony Concert | 20171215 | 28582 |  Denyse Bloomgren |   28582   |
# | SQL Symphony Concert | 20171202 | 81526 |    Odis Manteca   |   81526   |
# +----------------------+----------+-------+-------------------+-----------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# INSERT INTO solution VALUES (1, 'Insert the name of the person you found here');
# SELECT value FROM solution;
# Out:
# Running query in 'sqlite:///sql-murder-mystery.db'
# 1 rows affected.
# +-----------------------------------------+
# |                  value                  |
# +-----------------------------------------+
# | That's not the right person. Try again! |
# +-----------------------------------------+
